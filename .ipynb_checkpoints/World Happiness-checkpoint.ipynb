# %%
# Importing libraries needed for this project
import os
import pandas as pd
import sqlite3
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing csv file to notebook
Happiness2015 = pd.read_csv("2015.csv")
Happiness2015 = pd.read_csv("2015.csv")
Happiness2015 = pd.read_csv("2015.csv")

# %%
# Creating an sql database
tweets.to_sql('tweets', sqlite3.connect('TrumpTweets.db'), if_exists = "replace")
# Out:
# C:\Users\chris.givan\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:2531: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype, method=method)

# %%
# connectiong to SQL database
con = sqlite3.connect('TrumpTweets.db')
# Calling database
# tweets

# %%
# Making first variable to tweets_by_date to only show date of tweet, tweet, and how many times it was retweeted. 
tweets_by_date = pd.read_sql_query("SELECT Date AS TweetDate, Tweet_Text, Retweets FROM tweets ORDER BY TweetDate", con);

# %%
tweets_by_date
# Out:
#      TweetDate                                         Tweet_Text  Retweets
# 0     15-07-16  Thoughts and prayers to the families of the fo...      2957
# 1     15-07-16  .@GovernorPerry failed on the border. He shoul...      1458
# 2     15-07-16  .@GovernorPerry just gave a pollster quote on ...       363
# 3     15-07-16  .@SenJohnMcCain should be defeated in the prim...      1490
# 4     15-07-16  The thousands of people that showed up for me ...       898
# 5     15-07-16  CNN: "New GOP polls show Trumps favorability i...       314
# 6     15-07-16  No government ever voluntarily reduces itself ...      1322
# 7     15-07-16  More Bush cronyism  Jeb Bush and the Common Co...       394
# 8     15-07-16  We need leaders who can negotiate great deals ...       655
# 9     15-07-16  Leaving for New Hampshire now. Making a speech...       279
# 10    15-07-16  The Iran deal poses a direct national security...      1084
# ...

# %%
# Making variable to obama_tweets to only show tweets about Obama. 
obama_tweets = pd.read_sql_query("SELECT Date AS TweetDate, Tweet_Text, Retweets FROM tweets WHERE Tweet_Text LIKE '%Obama%' ORDER BY TweetDate", con);

# %%
obama_tweets
# Out:
#     TweetDate                                         Tweet_Text  Retweets
# 0    15-07-16  FLASHBACK  Donald Trump Blasts Obama for Faili...       455
# 1    15-07-18  Why would anybody listen to @MittRomney? He lo...      2499
# 2    15-07-18  In addition to doing a lousy job in taking car...      1176
# 3    15-07-21  Im glad President Obama followed my lead and l...      2300
# 4    15-07-21  "@AlbertoZambrano: @HeinzFGuderian   Well get ...       225
# 5    15-07-22  Its going to take an outsider to clean up afte...      1539
# 6    15-07-22  Obama still will keep all military recruitment...      2488
# 7    15-07-24  RT @mboyle1: Exclusive  .@RealDonaldTrump: Ira...       251
# 8    15-07-26  "@bluestarwindow: @realDonaldTrump @bdean1468 ...       274
# 9    15-07-27  .@SteveRattner While I think you should have g...       308
# 10   15-07-27  "@bollweevil51: @realDonaldTrump Great speech ...       274
# ...
