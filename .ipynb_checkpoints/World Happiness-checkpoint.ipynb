# %% [markdown]
# # The Happiest Place to live (2015-2017)

# %%
# Importing libraries needed for this project
import os
import pandas as pd
import glob
import sqlite3
import numpy as np
import matplotlib.pyplot as plt

# %%
# function to combine all csv files to 1 file
def concatenate(indir="in\\Extracted", outfile="../../out/Concatenated.csv"):
    os.chdir(indir)
    fileList=glob.glob("*.csv")
    dfList=[]
    colnames=["Year","Country","Region","HappinessRank","HappinessScore","Economy(GDPperCapita)","Family","Health(LifeExpectancy)","Freedom","Trust(GovernmentCorruption)","Generosity","DystopiaResidual"]
    for filename in fileList:
        print(filename)
        df=pd.read_csv(filename, skiprows=1, header=None)
        dfList.append(df)
    concatDf=pd.concat(dfList,axis=0)
    concatDf.columns=colnames
    concatDf.to_csv(outfile,index=None)

# %%
concatenate()
# Out:
# 2015.csv
# 2016.csv
# 2017.csv

# %%
happiness = pd.read_csv("../../out/Concatenated.csv")

# %%
happiness.to_sql('happiness', sqlite3.connect('WorldHappiness.db'), if_exists = "replace")

# %%
# happiness.info()

# %% [markdown]
# # Column Definitions
# ##### Year
# Year of survey.
# ##### Country
# Name of the country.
# ##### Region
# Region the country belongs to.
# ##### Happiness Rank
# Rank of the country based on the Happiness Score.
# ##### Happiness Score
# A metric measured in 2015 by asking the sampled people the question: "How would you rate your happiness on a scale of 0 to 10 where 10 is the happiest."
# ##### Economy (GDP per Capita)
# The extent to which GDP contributes to the calculation of the Happiness Score.
# ##### Family
# The extent to which Family contributes to the calculation of the Happiness Score
# ##### Health (Life Expectancy)
# The extent to which Life expectancy contributed to the calculation of the Happiness Score
# ##### Freedom
# The extent to which Freedom contributed to the calculation of the Happiness Score.
# ##### Trust (Government Corruption)
# The extent to which Perception of Corruption contributes to Happiness Score.
# ##### Generosity
# The extent to which Generosity contributed to the calculation of the Happiness Score.
# ##### Dystopia Residual
# The extent to which Dystopia Residual contributed to the calculation of the Happiness Score.

# %% [markdown]
# ## Full Dataset (2015, 2016, 2017)

# %%
# connectiong to SQL database
con = sqlite3.connect('WorldHappiness.db')
# Calling database
happiness
# Out:
#      Year                   Country                           Region  \
# 0    2015               Switzerland                   Western Europe
# 1    2015                   Iceland                   Western Europe
# 2    2015                   Denmark                   Western Europe
# 3    2015                    Norway                   Western Europe
# 4    2015                    Canada                    North America
# 5    2015                   Finland                   Western Europe
# 6    2015               Netherlands                   Western Europe
# 7    2015                    Sweden                   Western Europe
# 8    2015               New Zealand        Australia and New Zealand
# 9    2015                 Australia        Australia and New Zealand
# 10   2015                    Israel  Middle East and Northern Africa
# 11   2015                Costa Rica      Latin America and Caribbean
# 12   2015                   Austria                   Western Europe
# ...

# %%
top5_happiest_2015 = pd.read_sql_query("SELECT * FROM happiness WHERE CAST([HappinessRank] AS INT) <= 5 AND [Year] = 2015 ORDER BY Year, CAST([HappinessRank] AS INT)", con);
top5_happiest_2016 = pd.read_sql_query("SELECT * FROM happiness WHERE CAST([HappinessRank] AS INT) <= 5 AND [Year] = 2016 ORDER BY Year, CAST([HappinessRank] AS INT)", con);
top5_happiest_2017 = pd.read_sql_query("SELECT * FROM happiness WHERE CAST([HappinessRank] AS INT) <= 5 AND [Year] = 2017 ORDER BY Year, CAST([HappinessRank] AS INT)", con);
top10_happiest_avg = pd.read_sql_query("SELECT Country, MAX(Region) AS Region, AVG(CAST([HappinessScore] AS FLOAT)) AS AvgHappinessScore FROM happiness GROUP BY Country ORDER BY AVG(CAST([HappinessScore] AS FLOAT)) DESC LIMIT 10", con);

# %% [markdown]
# ## Top 5 happiest countries in 2015

# %%
top5_happiest_2015
# Out:
#    index  Year      Country          Region  HappinessRank  HappinessScore  \
# 0      0  2015  Switzerland  Western Europe              1           7.587
# 1      1  2015      Iceland  Western Europe              2           7.561
# 2      2  2015      Denmark  Western Europe              3           7.527
# 3      3  2015       Norway  Western Europe              4           7.522
# 4      4  2015       Canada   North America              5           7.427
#
#    Economy(GDPperCapita)   Family  Health(LifeExpectancy)  Freedom  \
# 0                1.39651  1.34951                 0.94143  0.66557
# 1                1.30232  1.40223                 0.94784  0.62877
# 2                1.32548  1.36058                 0.87464  0.64938
# 3                1.45900  1.33095                 0.88521  0.66973
# 4                1.32629  1.32261                 0.90563  0.63297
#
#    Trust(GovernmentCorruption)  Generosity  DystopiaResidual
# ...

# %% [markdown]
# ## Top 5 happiest countries in 2016

# %%
top5_happiest_2016
# Out:
#    index  Year      Country          Region  HappinessRank  HappinessScore  \
# 0    158  2016      Denmark  Western Europe              1           7.526
# 1    159  2016  Switzerland  Western Europe              2           7.509
# 2    160  2016      Iceland  Western Europe              3           7.501
# 3    161  2016       Norway  Western Europe              4           7.498
# 4    162  2016      Finland  Western Europe              5           7.413
#
#    Economy(GDPperCapita)   Family  Health(LifeExpectancy)  Freedom  \
# 0                1.44178  1.16374                 0.79504  0.57941
# 1                1.52733  1.14524                 0.86303  0.58557
# 2                1.42666  1.18326                 0.86733  0.56624
# 3                1.57744  1.12690                 0.79579  0.59609
# 4                1.40598  1.13464                 0.81091  0.57104
#
#    Trust(GovernmentCorruption)  Generosity  DystopiaResidual
# ...

# %% [markdown]
# ## Top 5 happiest countries in 2017

# %%
top5_happiest_2017
# Out:
#    index  Year      Country          Region  HappinessRank  HappinessScore  \
# 0    315  2017       Norway  Western Europe              1           7.537
# 1    316  2017      Denmark  Western Europe              2           7.522
# 2    317  2017      Iceland  Western Europe              3           7.504
# 3    318  2017  Switzerland  Western Europe              4           7.494
# 4    319  2017      Finland  Western Europe              5           7.469
#
#    Economy(GDPperCapita)    Family  Health(LifeExpectancy)   Freedom  \
# 0               1.616463  1.533524                0.796667  0.635423
# 1               1.482383  1.551122                0.792566  0.626007
# 2               1.480633  1.610574                0.833552  0.627163
# 3               1.564980  1.516912                0.858131  0.620071
# 4               1.443572  1.540247                0.809158  0.617951
#
#    Trust(GovernmentCorruption)  Generosity  DystopiaResidual
# ...

# %% [markdown]
# ## Top 10 Overall Happiest Countries (2015-2017)

# %%
top10_happiest_avg
# Out:
#        Country                     Region  AvgHappinessScore
# 0  Switzerland             Western Europe           7.530000
# 1      Denmark             Western Europe           7.525000
# 2      Iceland             Western Europe           7.522000
# 3       Norway             Western Europe           7.519000
# 4      Finland             Western Europe           7.429333
# 5       Canada              North America           7.382333
# 6  Netherlands             Western Europe           7.364667
# 7       Sweden             Western Europe           7.313000
# 8  New Zealand  Australia and New Zealand           7.311333
# 9    Australia  Australia and New Zealand           7.293667

# %%
# plot the results.
my_plot = top10_happiest_avg.plot(kind='bar', x='Country', y='AvgHappinessScore', legend=None,title="Top 10 Overall Happiest Countries (2015-2017)")
my_plot.set_xlabel("Country")
my_plot.set_ylabel("Overall Happiness Score")
my_plot.set_ylim([7.25,7.55])
# Out:
# (7.25, 7.55)

# %% [markdown]
# ### Now let's dig into the data and analyze the significant factors that attribute to the happiness scores

# %%
# top10_happiest_economy_2015 = pd.read_sql_query("SELECT Country, Region, CAST([Economy(GDPperCapita)] AS FLOAT) AS [Economy(GDPperCapita)] FROM happiness WHERE [Year] = 2015 ORDER BY CAST([Economy(GDPperCapita)] AS FLOAT) DESC LIMIT 10", con);
# top10_happiest_economy_2016 = pd.read_sql_query("SELECT Country, Region, CAST([Economy(GDPperCapita)] AS FLOAT) AS [Economy(GDPperCapita)] FROM happiness WHERE [Year] = 2016 ORDER BY CAST([Economy(GDPperCapita)] AS FLOAT) DESC LIMIT 10", con);
# top10_happiest_economy_2017 = pd.read_sql_query("SELECT Country, Region, CAST([Economy(GDPperCapita)] AS FLOAT) AS [Economy(GDPperCapita)] FROM happiness WHERE [Year] = 2017 ORDER BY CAST([Economy(GDPperCapita)] AS FLOAT) DESC LIMIT 10", con);
top10_happiest_economy_avg = pd.read_sql_query("SELECT Country, MAX(Region) AS Region, CAST(ROUND(AVG(CAST([HappinessRank] AS FLOAT)) ,0) AS INT) AS AvgHappinessRank, AVG(CAST([Economy(GDPperCapita)] AS FLOAT)) AS [Economy(GDPperCapita)] FROM happiness GROUP BY Country ORDER BY AVG(CAST([Economy(GDPperCapita)] AS FLOAT)) DESC LIMIT 10", con);

# %% [markdown]
# ## Top 10 Effect the Economy had on the Happiest Score (2015-2017)

# %%
top10_happiest_economy_avg
# Out:
#                 Country                           Region  AvgHappinessRank  \
# 0                 Qatar  Middle East and Northern Africa                33
# 1            Luxembourg                   Western Europe                18
# 2             Singapore                Southeastern Asia                24
# 3                Kuwait  Middle East and Northern Africa                40
# 4                Norway                   Western Europe                 3
# 5  United Arab Emirates  Middle East and Northern Africa                23
# 6           Switzerland                   Western Europe                 2
# 7         United States                    North America                14
# 8             Hong Kong                     Eastern Asia                73
# 9          Saudi Arabia  Middle East and Northern Africa                35
#
#    Economy(GDPperCapita)
# 0               1.795152
# 1               1.667791
# 2               1.619896
# 3               1.601437
# ...

# %%
# plot the results.
my_plot = top10_happiest_economy_avg.plot(kind='bar', x='Country', y='Economy(GDPperCapita)', legend=None,title="Top 10 Happiest Countries by Economy (2015-2017)")
my_plot.set_xlabel("Country")
my_plot.set_ylabel("Economy Happiness Score")
my_plot.set_ylim([1.45,1.85])
# Out:
# (1.45, 1.85)

# %%
# top10_happiest_family_2015 = pd.read_sql_query("SELECT Country, Region, CAST(Family AS FLOAT) AS Family FROM happiness WHERE [Year] = 2015 ORDER BY CAST(Family AS FLOAT) DESC LIMIT 10", con);
# top10_happiest_family_2016 = pd.read_sql_query("SELECT Country, Region, CAST(Family AS FLOAT) AS Family FROM happiness WHERE [Year] = 2016 ORDER BY CAST(Family AS FLOAT) DESC LIMIT 10", con);
# top10_happiest_family_2017 = pd.read_sql_query("SELECT Country, Region, CAST(Family AS FLOAT) AS Family FROM happiness WHERE [Year] = 2017 ORDER BY CAST(Family AS FLOAT) DESC LIMIT 10", con);
top10_happiest_family_avg = pd.read_sql_query("SELECT Country, MAX(Region) AS Region, CAST(ROUND(AVG(CAST([HappinessRank] AS FLOAT)) ,0) AS INT) AS AvgHappinessRank, AVG(CAST(Family AS FLOAT)) AS Family FROM happiness GROUP BY Country ORDER BY AVG(CAST(Family AS FLOAT)) DESC LIMIT 10", con);

# %% [markdown]
# ## Top 10 Happiest due to Family (2015-2017)

# %%
top10_happiest_family_avg
# Out:
#        Country                      Region  AvgHappinessRank    Family
# 0      Iceland              Western Europe                 3  1.398688
# 1      Ireland              Western Europe                17  1.363094
# 2      Denmark              Western Europe                 2  1.358481
# 3   Uzbekistan  Central and Eastern Europe                47  1.352500
# 4  New Zealand   Australia and New Zealand                 8  1.346882
# 5  Switzerland              Western Europe                 2  1.337221
# 6      Finland              Western Europe                 5  1.331049
# 7       Norway              Western Europe                 3  1.330458
# 8        Spain              Western Europe                36  1.325110
# 9    Australia   Australia and New Zealand                10  1.308011

# %%
# plot the results.
my_plot = top10_happiest_family_avg.plot(kind='bar', x='Country', y='Family', legend=None,title="Top 10 Happiest Countries by Family (2015-2017)")
my_plot.set_xlabel("Country")
my_plot.set_ylabel("Family Happiness Score")
my_plot.set_ylim([1.3,1.42])
# Out:
# (1.3, 1.42)

# %%
top10_happiest_health_avg = pd.read_sql_query("SELECT Country, MAX(Region) AS Region, AVG(CAST([Health(LifeExpectancy)] AS FLOAT)) AS [Health(LifeExpectancy)] FROM happiness GROUP BY Country ORDER BY AVG(CAST([Health(LifeExpectancy)] AS FLOAT)) DESC LIMIT 10", con);

# %% [markdown]
# ## Top 10 Happiest due to Health/Life Expectancy (2015-2017)

# %%
top10_happiest_health_avg
# Out:
#        Country                     Region  Health(LifeExpectancy)
# 0    Singapore          Southeastern Asia                0.973977
# 1    Hong Kong               Eastern Asia                0.969704
# 2        Japan               Eastern Asia                0.939832
# 3  South Korea               Eastern Asia                0.917348
# 4        Spain             Western Europe                0.907847
# 5  Switzerland             Western Europe                0.887530
# 6        Italy             Western Europe                0.886208
# 7      Iceland             Western Europe                0.882907
# 8       France             Western Europe                0.876069
# 9    Australia  Australia and New Zealand                0.875549

# %%
# plot the results.
my_plot = top10_happiest_health_avg.plot(kind='bar', x='Country', y='Health(LifeExpectancy)', legend=None,title="Top 10 Happiest Countries by Health (2015-2017)")
my_plot.set_xlabel("Country")
my_plot.set_ylabel("Health Happiness Score")
my_plot.set_ylim([0.86,0.98])
# Out:
# (0.86, 0.98)

# %%
top10_happiest_freedom_avg = pd.read_sql_query("SELECT Country, MAX(Region) AS Region, AVG(CAST(Freedom AS FLOAT)) AS Freedom FROM happiness GROUP BY Country ORDER BY AVG(CAST(Freedom AS FLOAT)) DESC LIMIT 10", con);

# %% [markdown]
# ## Top 10 Happiest due to Freedom (2015-2017)

# %%
top10_happiest_freedom_avg
# Out:
#        Country                           Region   Freedom
# 0   Uzbekistan       Central and Eastern Europe  0.641646
# 1       Norway                   Western Europe  0.633748
# 2         Oman  Middle East and Northern Africa  0.632740
# 3     Cambodia                Southeastern Asia  0.628119
# 4  Switzerland                   Western Europe  0.623737
# 5       Sweden                   Western Europe  0.618301
# 6      Denmark                   Western Europe  0.618266
# 7  New Zealand        Australia and New Zealand  0.611637
# 8      Finland                   Western Europe  0.610227
# 9      Iceland                   Western Europe  0.607391

# %%
# plot the results.
my_plot = top10_happiest_freedom_avg.plot(kind='bar', x='Country', y='Freedom', legend=None,title="Top 10 Happiest Countries by Freedom (2015-2017)")
my_plot.set_xlabel("Country")
my_plot.set_ylabel("Freedom Happiness Score")
my_plot.set_ylim([0.6,0.65])
# Out:
# (0.6, 0.65)

# %%
top10_happiest_trust_avg = pd.read_sql_query("SELECT Country, MAX(Region) AS Region, AVG(CAST([Trust(GovernmentCorruption)] AS FLOAT)) AS [Trust(GovernmentCorruption)] FROM happiness GROUP BY Country ORDER BY AVG(CAST([Trust(GovernmentCorruption)] AS FLOAT)) DESC LIMIT 10", con);

# %% [markdown]
# ## Top 10 Happiest due to Trust in Government (2015-2017)

# %%
top10_happiest_trust_avg
# Out:
#              Country                           Region  \
# 0             Rwanda               Sub-Saharan Africa
# 1              Qatar  Middle East and Northern Africa
# 2          Singapore                Southeastern Asia
# 3            Denmark                   Western Europe
# 4             Sweden                   Western Europe
# 5        New Zealand        Australia and New Zealand
# 6            Finland                   Western Europe
# 7        Switzerland                   Western Europe
# 8  Somaliland region               Sub-Saharan Africa
# 9  Somaliland Region               Sub-Saharan Africa
#
#    Trust(GovernmentCorruption)
# 0                     0.504113
# 1                     0.480623
# 2                     0.475426
# 3                     0.442957
# 4                     0.410503
# 5                     0.410359
# 6                     0.402124
# 7                     0.399606
# 8                     0.399280
# 9                     0.367940

# %%
# plot the results.
my_plot = top10_happiest_trust_avg.plot(kind='bar', x='Country', y='Trust(GovernmentCorruption)', legend=None,title="Top 10 Happiest Countries by Trust in Government (2015-2017)")
my_plot.set_xlabel("Country")
my_plot.set_ylabel("Trust(GovernmentCorruption) Happiness Score")
my_plot.set_ylim([0.35,0.52])
# Out:
# (0.35, 0.52)

# %% [markdown]
# ## Change data to reflect only the top 5 countries
